# %% [markdown]
# # Day 9: Introduction to Plotting (featuring Gen-AI 🤖)

# %% [markdown]
# ### &#9989; Write your name here

# %% [markdown]
# In this assignment, we will begin creating plots using the Python library Matplotlib. The import statement has been included for you. Run the code cell below to gain access to NumPy functions through `np` and Matplotlib functions (specifically, Matplotlib's pyplot interface) through `plt`.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Making a plot in Matplotlib comes with a basic checklist:
# 1. An array of $x$-values
# 2. An equally sized array of $y$-values (if plotting on 2 axes)
# 3. A plotting command, to create the plot
# 4. A `show` command, to display the plot in your interface
#
# For instance, if we want to plot $\sin(x)$ in the range $0 \le x \le 2\pi$, we would first create an array of values for $x$:

# %%
x = np.linspace(0, 2*np.pi, 100)

# %% [markdown]
# Note that computers always work with a finite number of values, so you cannot really plot $\sin(x)$ *continuously* in the range $0 \le x \le 2\pi$. What we can do is "discretize" $x$ within the desired range. The NumPy command above, for example, creates 100 values for $x$ in the range $\left[0,2\pi\right]$.
#
# Once you have your independent variable, you can create corresponding y-values. Because we need an equal number of x and y values, we can use NumPy operations, which preserve the size of an array.

# %%
y = np.sin(x)

# %% [markdown]
# Now that we have equally sized x and y arrays, we can plot them. If you want to emphasize the discrete nature of the arrays, `scatter` is a good command.

# %%
# plotting command "scatter" creates a scatterplot
plt.scatter(x, y)
# plt.show() shows the plot in your interface
plt.show()

# %% [markdown]
# Alternatively, you can use `plot` to instruct the computer to draw a line between each subsequent point, creating the illusion of a continuous curve.

# %%
# plotting command "plot" creates a connected curve
plt.plot(x, y)
# plt.show() shows the plot in your interface
plt.show()

# %% [markdown]
# Lastly, we can add labels to our plot to make the information and purpose more clear to whoever is viewing it. The computer will create a plot regardless, but you should **always** add labels for visual clarity, unless they would add unnecessary clutter.

# %%
plt.plot(x, y)

# xlabel and ylabel create axis labels
plt.xlabel("x")
plt.ylabel("sin(x)")

# title creates a title over the top of the plot
plt.title("Example of sine wave")

# always place the "show" command at the very end
plt.show()

# %% [markdown]
# ---
#
# ### Part 1: Plotting Exercises
#
# The exercises here are designed to give you practice creating basic plots using Matplotlib. This involves generating arrays and making plotting commands, but it also involves looking up some information on your own.
#
# A library like Matplotlib, which creates visual outputs, has nearly unlimited options for customizing plots and figures. These options lie mostly outside the scope of this course, but one skill you **can** build here is learning where to look for miscellaneous plotting functionalities, and practicing applying that outside information to your own plots.

# %% [markdown]
# **&#9989; Task 1.1:** Create a plot of $x^2$, over a span of x-values of your choosing. Include axis labels and a title.

# %%
# your answer here

# %% [markdown]
# **&#9989; Task 1.2:** Copy your code from above, and add a second plot of $\sqrt{x}$ on the *same set of axes*. Update your labels and title accordingly.

# %%
# your answer here

# %% [markdown]
# **&#9989; Task 1.3:**
# It might be hard to know how to label the figure to easily tell the difference between which plot is which. One handy plotting tool is a **legend**. Try adding a legend to your visualization. You may need to search online how to execute this idea.

# %%
# your answer here

# %% [markdown]
# #### &#128721; **Stop here and check your progress with an instructor.**

# %% [markdown]
# ---
#
# ### Part 2: Plotting Special Relativity
#
# Let's use our newly acquired programming skills to explore special relativity concepts. The Lorentz factor $\Gamma$ is defined as:
#
# $$\Gamma = \frac{1}{\sqrt{1-\frac{v^2}{c^2}}}$$
#
# Where $v$ is the speed of a physical object and $c= 3 \cdot 10^8 \text{ m/s}$ is the speed of light.

# %% [markdown]
# **&#9989; Task 2.1:** Make a plot of $\Gamma$ vs. $v$  for $0 \le v \lt c$. Include appropriate axis labels and title.
#
# *Note: "y vs. x" means y goes on y-axis, x goes on x-axis*.
#
# **&#129302; Gen-AI mini task**: Ask your favorite Gen-AI to help you create this plot. You can choose whichever Gen-AI you like (some options are ChatGPT, Microsoft Copilot, Bard, etc.), and you can use it to help you however much you like. Further below, you'll need to describe how you used it.

# %%
# your answer here

# %% [markdown]
# **&#9989; Task 2.2:** In Task 2.1, you were asked to use Gen-AI. Below, **describe the level of usage**. Some questions to consider:
# - Did it help you brainstorm your own ideas?
# - Did you use an idea that Gen-AI provided?
# - Did you use code from gen-AI, but made it your own through significant changes?
# - Did you use code directly with minimal editing?
#
# Also, **provide an attribution** by describing how your final solution reflects the Gen-AI output:
# - What did you ask for in when prompting Gen-AI?
# - What did you get in response from Gen-AI?
# - What did you choose to keep from your conversation, and how did you alter it for your own solution?

# %% [markdown]
# **/your answer here/**

# %% [markdown]
# **&#9989; Task 2.3:** There is an approximation for $\Gamma$ when $v \ll c$, which comes from a Taylor Series expansion:
#
# $$\Gamma \approx 1 + \frac{v^2}{2c^2}$$
#
# What span of values for $v$ do you think this will be a good approximation? Note, there is no "correct" span of values, and this depends on your own idea of a "good" approximation. It's okay to take a guess or estimate here. Below, describe your chosen **span of values and your reasoning.**

# %% [markdown]
# **/your answer here/**

# %% [markdown]
# **&#9989; Task 2.4:** Copy your visualization code from Task 2.1, and:
# - **Add this approximation to it**.
# - Include **labels and a legend** to differentiate between the curves.
# - Use the functions `xlim` and `ylim` to **zoom into the area** of the plot that helps you see your chosen span (from Task 2.3) the best.
#
# **&#129302; Gen-AI mini task**: Ask your favorite Gen-AI to help you execute this task. You can choose whichever Gen-AI you like, and you can use it to help you however much you like. Further below, you'll need to describe how you used it.

# %%
# your answer here

# %% [markdown]
# **&#9989; Task 2.5:** Describe how "good" you think the approximation is. In your description, use evidence from your work by visually comparing the curves on your zoomed-in plot from Task 2.4.
#
# **&#129302; Gen-AI mini task**: Ask your favorite Gen-AI to help you make this comparison and decide on the "goodness" of the approximation. You can choose whichever Gen-AI you like, and you can use it to help you however much you like. Further below, you'll need to describe how you used it.

# %% [markdown]
# **/your answer here/**

# %% [markdown]
# **&#9989; Task 2.6:** In Tasks 2.4 and 2.5, you were asked to use Gen-AI. Below, **describe the level of usage**. Some questions to consider:
# - Did it help you better understand zooming in or other plotting tools?
# - Did it help you brainstorm ideas about how to use them?
# - Did you use code from Gen-AI, but make it your own through significant changes?
# - Did you borrow an explanation from Gen-AI and edit it into your own words?
# - Did you use explanations and/or code directly with minimal editing?
#
# Also, **provide an attribution** by describing how your final solution reflects the Gen-AI output:
# - What did you ask for in when prompting Gen-AI?
# - What did you get in response from Gen-AI?
# - What did you choose to keep from your conversation, and how did you alter it for your own solution and explanation?

# %% [markdown]
# **/your answer here/**

# %% [markdown]
# #### &#128721; **Stop here and check in with an instructor. Do not leave yet -- we will have larger discussions about Gen-AI before class ends.**
